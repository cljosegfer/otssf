# %% [markdown]
# read all spells and create a table with all relevant information

# %% [markdown]
# # setup

# %%
import os
import re
import pandas as pd
import numpy as np

from tqdm import tqdm

# %% [markdown]
# # utils

# %%
def parse_argument(arg):
    arg = arg.strip()
    if not arg:
        return None
    if arg == 'true':
        return True
    elif arg == 'false':
        return False
    elif arg == 'nil':
        return None
    if (arg.startswith('"') and arg.endswith('"')) or (arg.startswith("'") and arg.endswith("'")):
        return arg[1:-1]
    else:
        try:
            return eval(arg)
        except NameError:
            return arg
        except:
            return arg

# %%
def split_arguments(s):
    args = []
    current = []
    in_quote = None
    escape = False
    for c in s:
        if escape:
            current.append(c)
            escape = False
        elif c == '\\':
            escape = True
        elif in_quote:
            if c == in_quote:
                in_quote = None
            current.append(c)
        elif c in ('"', "'"):
            in_quote = c
            current.append(c)
        elif c == ',' and not in_quote:
            args.append(''.join(current).strip())
            current = []
        else:
            current.append(c)
    if current:
        args.append(''.join(current).strip())
    return args

# %%
def parse_spell_file(file_path):
    spell_dict = {}
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.split('--')[0].strip()
            if line.startswith('spell:'):
                match = re.match(r'spell:(\w+)\((.*)\)', line)
                if match:
                    method = match.group(1)
                    params_str = match.group(2)
                    args = split_arguments(params_str)
                    parsed_args = [parse_argument(arg) for arg in args if arg]
                    if parsed_args:
                        spell_dict[method] = parsed_args[0] if len(parsed_args) == 1 else parsed_args
    return spell_dict

# %% [markdown]
# # main

# %%
root_dir = '.'

# %%
spells = []
for root, _, files in tqdm(os.walk(root_dir)):
    for file in files:
        if file.endswith('.lua'):
            file_path = os.path.join(root, file)
            spell_dict = parse_spell_file(file_path)
            if spell_dict:
                spell_dict['path'] = file_path
                spells.append(spell_dict)
# Out:
# 8it [00:00, 147.53it/s]

# %%
file, spell_dict
# Out:
# ('sorcerer_familiar.lua',
#  {'group': 'support',
#   'id': 'spellId',
#   'name': 'Sorcerer familiar',
#   'words': 'utevo gran res ven',
#   'castSound': 'SOUND_EFFECT_TYPE_SPELL_SUMMON_SORCERER_FAMILIAR',
#   'level': 200,
#   'mana': 3000,
#   'cooldown': 0,
#   'groupCooldown': 2000,
#   'needLearn': False,
#   'isAggressive': False,
#   'vocation': ['sorcerer;true', 'master sorcerer;true'],
#   'path': './familiar/sorcerer_familiar.lua'})

# %%
df = pd.DataFrame(spells)
len(df), len(df.columns), df.columns
# Out:
# (174,
#  31,
#  Index(['name', 'runeId', 'id', 'level', 'magicLevel', 'needTarget',
#         'isAggressive', 'allowFarUse', 'charges', 'vocation', 'path', 'words',
#         'group', 'castSound', 'cooldown', 'groupCooldown', 'mana', 'soul',
#         'needLearn', 'isPremium', 'isSelfTarget', 'hasParams',
#         'hasPlayerNameParam', 'range', 'needCasterTargetOrDirection',
#         'blockWalls', 'needDirection', 'isBlockingWalls', 'allowOnSelf',
#         'impactSound', 'needWeapon'],
#        dtype='object'))

# %%
# Convert numeric columns to integers (handling NaNs)
numeric_cols = ['id', 'level', 'magicLevel', 'mana', 'soul', 'cooldown', 'groupCooldown', 'range']
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

# %%
# Helper function to check if a vocation is allowed
def has_vocation(voc_list, target):
    if not isinstance(voc_list, list):
        # Handle cases where only one vocation was provided as a string
        return target.lower() in str(voc_list).lower()
    return any(target.lower() in v.lower() for v in voc_list)

# %%
# Create a clean boolean column for Sorcerers
df['is_sorcerer'] = df['vocation'].apply(lambda x: has_vocation(x, 'sorcerer'))

# %%
np.unique(df['id'])
# Out:
# array([   0,    1,    2,    3,    6,    9,   10,   11,   13,   19,   20,
#          22,   23,   24,   29,   36,   38,   39,   42,   43,   44,   45,
#          48,   49,   51,   56,   57,   59,   61,   62,   75,   76,   79,
#          80,   81,   82,   84,   87,   88,   89,   90,   92,   93,   95,
#         105,  106,  107,  108,  109,  110,  111,  112,  113,  118,  119,
#         120,  121,  122,  123,  124,  125,  126,  127,  128,  129,  131,
#         132,  133,  134,  135,  138,  139,  140,  141,  142,  143,  144,
#         145,  146,  147,  148,  149,  150,  151,  152,  153,  154,  155,
#         156,  157,  158,  159,  160,  166,  167,  169,  170,  173,  174,
#         176,  177,  178,  191,  220,  237,  238,  239,  240,  241,  242,
#         243,  244,  245,  258,  260,  261,  262,  263,  264,  265,  266,
#         267,  268, 1000])

# %%
df.loc[df['id'] == 81]
# Out:
#         name  runeId  id  level  magicLevel needTarget isAggressive  \
# 13  Levitate     NaN  81     12           0        NaN        False
#
#    allowFarUse  charges                                           vocation  \
# 13         NaN      NaN  [druid;true, elder druid;true, knight;true, el...
#
#     ... hasPlayerNameParam range needCasterTargetOrDirection blockWalls  \
# 13  ...                NaN     0                         NaN        NaN
#
#     needDirection  isBlockingWalls  allowOnSelf  impactSound needWeapon  \
# 13            NaN              NaN          NaN          NaN        NaN
#
#    is_sorcerer
# 13        True
#
# [1 rows x 32 columns]

# %%
print("--- ID CONFLICT CHECK ---")
duplicates = df[df.duplicated('id', keep=False) & (df['id'] != 0)]

if not duplicates.empty:
    print(f"⚠️ Found {len(duplicates)} spells with conflicting IDs:")
    display(duplicates[['id', 'name', 'words', 'path']].sort_values('id'))
else:
    print("✅ All spell IDs are unique.")
# Out:
# --- ID CONFLICT CHECK ---
# ⚠️ Found 6 spells with conflicting IDs:
#       id                      name             words  \
# 5     20               Find Person             exiva
# 27    20                Find Fiend     exiva moe res
# 47    92             Enchant Staff         exeta vis
# 73    92  Conjure Wand of Darkness   exevo gran mort
# 99   174               Magic Patch       exura infir
# 165  174                Mud Attack  exori infir tera
#
#                                          path
# 5                   ./support/find_person.lua
# 27                   ./support/find_fiend.lua
# 47              ./conjuring/enchant_staff.lua
# 73   ./conjuring/conjure_wand_of_darkness.lua
# 99                  ./healing/magic_patch.lua
# 165                   ./attack/mud_attack.lua

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    # Filter, Sort by Level, then by ID
    sorc_df = df[df['is_sorcerer']].sort_values(by=['level', 'id'], ascending=[True, True])

    # Display relevant columns for a quick overview
    display(sorc_df[['level', 'id', 'name', 'words', 'mana', 'group']])
# Out:
#      level    id                      name                 words  mana  \
# 82       1     0   Light Stone Shower Rune  adori infir mas tera     6
# 85       1     0     Lightest Missile Rune       adori infir vis     6
# 99       1   174               Magic Patch           exura infir     6
# 137      1   177                      Buzz       exori infir vis     6
# 120      1   178                    Scorch  exevo infir flam hur     8
# 22       7  1000                     Blink             exani lux     0
# 92       8     1             Light Healing                 exura    20
# 25       8    10                     Light             utevo lux    20
# 5        8    20               Find Person                 exiva    20
# 146      8   169       Apprentice's Strike        exori min flam     6
# 28       9    76                Magic Rope            exani tera    20
# 93      10    29               Cure Poison             exana pox    30
# 13      12    81                  Levitate             exani hur    50
# 142     12    88             Energy Strike             exori vis    20
# 8       13    11               Great Light        utevo gran lux    60
# 149     13   113              Terra Strike            exori tera    20
# 71      14     0         Poison Field Rune        adevo grav pox   200
# 6       14     6                     Haste             utani hur    60
# 17      14    44              Magic Shield            utamo vita    50
# 134     14    89              Flame Strike            exori flam    20
# 4       14   245       Cancel Magic Shield            exana vita    50
# 41      15     0           Fire Field Rune       adevo grav flam   240
# 46      15     0  Light Magic Missile Rune         adori min vis   120
# 121     15   112                Ice Strike           exori frigo    20
# 138     16    87              Death Strike            exori mort    20
# 44      17     0        Destroy Field Rune            adito grav   120
# 83      18     0         Energy Field Rune        adevo grav vis   320
# 156     18    19                 Fire Wave        exevo flam hur    25
# 76      20     0                Blank Rune           adori blank    50
# 109     20     2           Intense Healing            exura gran    70
# 11      20    39              Strong Haste        utani gran hur   100
# 0       20   220                 test rune                   NaN     0
# 68      21     0         Disintegrate Rune            adito tera   200
# 122     23    22               Energy Beam         exevo vis lux    40
# 16      23    38         Creature Illusion         utevo res ina   100
# 50      24     0           Stalagmite Rune            adori tera   350
# 78      25     0  Heavy Magic Missile Rune             adori vis   350
# 20      25     9           Summon Creature             utevo res     0
# 27      25    20                Find Fiend         exiva moe res    20
# 3       26    75            Ultimate Light         utevo vis lux   140
# 152     26   138                    Ignite            utori flam    30
# 58      27     0         Animate Dead Rune            adana mort   600
# 72      27     0            Fire Bomb Rune        adevo mas flam   600
# 77      27     0             Fireball Rune            adori flam   460
# 84      27     0             Soulfire Rune        adevo res flam   420
# 60      28     0         Thunderstorm Rune         adori mas vis   430
# 43      29     0          Poison Wall Rune    adevo mas grav pox   640
# 130     29    23         Great Energy Beam    exevo gran vis lux   110
# 52      30     0       Great Fireball Rune        adori mas flam   530
# 88      30     3          Ultimate Healing            exura vita   160
# 67      31     0            Explosion Rune         adevo mas hur   570
# 79      32     0           Magic Wall Rune       adevo grav tera   750
# 111     32   129             Enchant Party         utori mas sio   120
# 81      33     0            Fire Wall Rune   adevo mas grav flam   780
# 151     34   140                 Electrify             utori vis    30
# 19      35    45              Invisibility             utana vid   440
# 64      37     0          Energy Bomb Rune         adevo mas vis   880
# 133     38    13               Energy Wave         exevo vis hur   170
# 163     38   240           Great Fire Wave   exevo gran flam hur   120
# 49      41     0          Energy Wall Rune    adevo mas grav vis  1000
# 47      41    92             Enchant Staff             exeta vis    80
# 73      41    92  Conjure Wand of Darkness       exevo gran mort   250
# 61      45     0         Sudden Death Rune       adori gran mort   985
# 168     55   119         Rage of the Skies    exevo gran mas vis   600
# 119     55   149                 Lightning         exori amp vis    60
# 117     60    24               Hell's Core   exevo gran mas flam  1100
# 148     70   150       Strong Flame Strike       exori gran flam    60
# 160     75   139                     Curse            utori mort    30
# 126     80   151      Strong Energy Strike        exori gran vis    60
# 136     90   154     Ultimate Flame Strike        exori max flam   100
# 116    100   155    Ultimate Energy Strike         exori max vis   100
# 173    200     0         Sorcerer familiar    utevo gran res ven  3000
# 32     275   243           Expose Weakness             exori moe   400
# 31     275   244              Sap Strength             exori kor   300
# 107    300   241               Restoration        exura max vita   260
# 158    300   260          Great Death Beam        exevo max mort   140
# 24     300   266           Avatar of Storm         uteta res ven  2200
#
#                          group
# 82                     support
# 85                     support
# 99                     healing
# 137                     attack
# 120                     attack
# 22                     support
# 92                     healing
# 25                     support
# 5                      support
# 146                     attack
# 28                     support
# 93                     healing
# 13                     support
# 142                     attack
# 8                      support
# 149                     attack
# 71                     support
# 6                      support
# 17                     support
# 134                     attack
# 4                      support
# 41                     support
# 46                     support
# 121                     attack
# 138                     attack
# 44                     support
# 83                     support
# 156                     attack
# 76                     support
# 109                    healing
# 11                     support
# 0                          NaN
# 68                     support
# 122                     attack
# 16                     support
# 50                     support
# 78                     support
# 20                     support
# 27                     support
# 3                      support
# 152                     attack
# 58                     support
# 72                     support
# 77                     support
# 84                     support
# 60                     support
# 43                     support
# 130       [attack, greatbeams]
# 52                     support
# 88                     healing
# 67                     support
# 79                     support
# 111                    support
# 81                     support
# 151                     attack
# 19                     support
# 64                     support
# 133                     attack
# 163                     attack
# 49                     support
# 47                     support
# 73                     support
# 61                     support
# 168            [attack, focus]
# 119          [attack, special]
# 117            [attack, focus]
# 148          [attack, special]
# 160                     attack
# 126          [attack, special]
# 136  [attack, ultimatestrikes]
# 116  [attack, ultimatestrikes]
# 173                    support
# 32        [support, crippling]
# 31        [support, crippling]
# 107                    healing
# 158       [attack, greatbeams]
# 24                     support

# %%
# df.to_csv('spells.csv')
